# %%
import control
import numpy as np
import matplotlib.pyplot as plt
import seibot.filter

sc_pool = seibot.filter.FilterPool("../config/sensor_correction_filters.ini")
lp_pool = seibot.filter.FilterPool("../config/low_pass_filters.ini")
hp_pool = seibot.filter.FilterPool("../config/high_pass_filters.ini")

filter_configuration = seibot.filter.FilterConfigurations(sc_pool=sc_pool, lp_pool=lp_pool, hp_pool=hp_pool)
filter_configuration(1, 2)

s = control.tf("s")
# sc_cal = 1/s
wn = 2*np.pi
q = 1/np.sqrt(2)
hp_cal = 1/s**3 * (s**2 + wn/q*s + wn**2)
f = np.logspace(-3, 3, 1024)

# plt.loglog(f, abs((1/sc_cal*sc_pool()[0])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[1])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[2])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[3])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[4])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[5])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[6])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[7])(1j*2*np.pi*f)))
# plt.loglog(f, abs((1/sc_cal*sc_pool()[8])(1j*2*np.pi*f)))

# plt.loglog(f, abs(filter_pool()[1](1j*2*np.pi*f)))

# %%
import seibot


ham8 = seibot.Seibot("../config/example_config.ini")
except:
    print(f)
# Out:
# CDS error

# %%
filter_config = ham8.filter_configurations

# %%
sc = filter_config(1, 1)["sensor correction filter"]
lp = filter_config(1, 1)["low pass filter"]
hp = filter_config(1, 1)["high pass filter"]

# hp /= hp_cal
# (lp, hp) = filter_configuration(1, 2)

# %%
plt.loglog(f, abs(sc(1j*2*np.pi*f)))
plt.loglog(f, abs(lp(1j*2*np.pi*f)))
plt.loglog(f, abs(hp(1j*2*np.pi*f)))

# %%
for filter_ in sc_pool:
    plt.loglog(f, abs(filter_(1j*2*np.pi*f)))

# %%
plt.loglog(f, abs((lp_pool()[0])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[1])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[2])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[3])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[4])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[5])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[6])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[7])(1j*2*np.pi*f)))
plt.loglog(f, abs((lp_pool()[8])(1j*2*np.pi*f)))

plt.loglog(f, abs((1/hp_cal*hp_pool()[0])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[1])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[2])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[3])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[4])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[5])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[6])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[7])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[8])(1j*2*np.pi*f)))

# %%
plt.loglog(f, abs((1/hp_cal*hp_pool()[0])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[1])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[2])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[3])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[4])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[5])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[6])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[7])(1j*2*np.pi*f)))
plt.loglog(f, abs((1/hp_cal*hp_pool()[8])(1j*2*np.pi*f)))

# %%
abs((1/hp_cal*hp_pool()[0])(1000000000))
# Out:
# 39.45574429526387

# %%
2*np.pi*2*np.pi
# Out:
# 39.47841760435743

# %%
filter_pool()[0].foton_file
# Out:
# '../foton_files/L1ISIHAM8.txt'

# %%
import numpy as np
import matplotlib.pyplot as plt

f = np.logspace(-3, 3, 1024)

plt.loglog(f, abs(filter_pool()[0](1j*2*np.pi*f)))
plt.loglog(f, abs(filter_pool()[1](1j*2*np.pi*f)))
